# %%
import pandas as pd 
import os
from google.cloud import storage

# %%
# Download green / yellow parquet files
colors = ['green', 'yellow']
years = [2019, 2020]
months = range(1,12+1)
for color in colors:
    for year in years:
        for month in months:
            url = f'https://d37ci6vzurychx.cloudfront.net/trip-data/{color}_tripdata_{year}-{month:02}.parquet'
            os.system(f'wget -q -N -P {color}_tripdata/ {url}')
            print(f'{color}{year}-{month:02} downloaded!')
# Out:
# green2019-01 downloaded!
# green2019-02 downloaded!
# green2019-03 downloaded!
# green2019-04 downloaded!
# green2019-05 downloaded!
# green2019-06 downloaded!
# green2019-07 downloaded!
# green2019-08 downloaded!
# green2019-09 downloaded!
# green2019-10 downloaded!
# green2019-11 downloaded!
# green2019-12 downloaded!
# green2020-01 downloaded!
# green2020-02 downloaded!
# green2020-03 downloaded!
# green2020-04 downloaded!
# green2020-05 downloaded!
# green2020-06 downloaded!
# green2020-07 downloaded!
# green2020-08 downloaded!
# green2020-09 downloaded!
# green2020-10 downloaded!
# green2020-11 downloaded!
# green2020-12 downloaded!
# yellow2019-01 downloaded!
# yellow2019-02 downloaded!
# yellow2019-03 downloaded!
# yellow2019-04 downloaded!
# yellow2019-05 downloaded!
# yellow2019-06 downloaded!
# yellow2019-07 downloaded!
# yellow2019-08 downloaded!
# yellow2019-09 downloaded!
# yellow2019-10 downloaded!
# yellow2019-11 downloaded!
# yellow2019-12 downloaded!
# yellow2020-01 downloaded!
# yellow2020-02 downloaded!
# yellow2020-03 downloaded!
# yellow2020-04 downloaded!
# yellow2020-05 downloaded!
# yellow2020-06 downloaded!
# yellow2020-07 downloaded!
# yellow2020-08 downloaded!
# yellow2020-09 downloaded!
# yellow2020-10 downloaded!
# yellow2020-11 downloaded!
# yellow2020-12 downloaded!

# %%
# Download 2019 fhv
year = 2019 
for month in months:
    url = f'https://d37ci6vzurychx.cloudfront.net/trip-data/fhv_tripdata_2019-{month:02}.parquet'
    os.system(f'wget -q -N -P fhv_tripdata/ {url}')
    print(f'fhv {year}-{month:02} downloaded!')
# Out:
# fhv 2019-01 downloaded!
# fhv 2019-02 downloaded!
# fhv 2019-03 downloaded!
# fhv 2019-04 downloaded!
# fhv 2019-05 downloaded!
# fhv 2019-06 downloaded!
# fhv 2019-07 downloaded!
# fhv 2019-08 downloaded!
# fhv 2019-09 downloaded!
# fhv 2019-10 downloaded!
# fhv 2019-11 downloaded!
# fhv 2019-12 downloaded!

# %%
# Load downloaded data to GCS bucket
bucket_name = 'de-zoomcamp-dominik-1'

# %%
# Imports the Google Cloud client library
# Instantiates a client
storage_client = storage.Client()

# %%
# Template to load data to GCS 
def upload_blob(bucket_name, source_file_name, destination_blob_name):
  storage_client = storage.Client()
  bucket = storage_client.get_bucket(bucket_name)
  blob = bucket.blob(destination_blob_name)
  blob.upload_from_filename(source_file_name)

# %%
# Load yellow and green taxitrips to bucket
for color in colors:
    for year in years:
        for month in months: 
            upload_blob(bucket_name, 
                        f'{color}_tripdata/{color}_tripdata_{year}-{month:02}.parquet',
                        f'week_4/{color}_tripdata/{color}_tripdata_{year}-{month:02}.parquet')

# %%
# Load fhv trips to bucket
for month in months:
    upload_blob(bucket_name,
                        f'fhv_tripdata/fhv_tripdata_{year}-{month:02}.parquet',
                        f'week_4/fhv_tripdata/fhv_tripdata_{year}-{month:02}.parquet'
               )
    print(f'{month} done')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connection.py:409, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     408         else:
# --> 409             self.send(chunk)
#     411 # Regardless of whether we have a body or not, if we're in
#     412 # chunked mode we want to send an explicit empty chunk.
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1009, in HTTPConnection.send(self, data)
#    1008 try:
# -> 1009     self.sock.sendall(data)
#    1010 except TypeError:
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1274, in SSLSocket.sendall(self, data, flags)
#    1273 while count < amount:
# -> 1274     v = self.send(byte_view[count:])
#    1275     count += v
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1243, in SSLSocket.send(self, data, flags)
#    1240         raise ValueError(
#    1241             "non-zero flags not allowed in calls to send() on %s" %
#    1242             self.__class__)
# -> 1243     return self._sslobj.write(data)
#    1244 else:
#
# TimeoutError: The write operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File /usr/local/lib/python3.11/site-packages/urllib3/util/retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File /usr/local/lib/python3.11/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connection.py:409, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     408         else:
# --> 409             self.send(chunk)
#     411 # Regardless of whether we have a body or not, if we're in
#     412 # chunked mode we want to send an explicit empty chunk.
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1009, in HTTPConnection.send(self, data)
#    1008 try:
# -> 1009     self.sock.sendall(data)
#    1010 except TypeError:
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1274, in SSLSocket.sendall(self, data, flags)
#    1273 while count < amount:
# -> 1274     v = self.send(byte_view[count:])
#    1275     count += v
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1243, in SSLSocket.send(self, data, flags)
#    1240         raise ValueError(
#    1241             "non-zero flags not allowed in calls to send() on %s" %
#    1242             self.__class__)
# -> 1243     return self._sslobj.write(data)
#    1244 else:
#
# ProtocolError: ('Connection aborted.', TimeoutError('The write operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Load fhv trips to bucket
#       2 for month in months:
# ----> 3     upload_blob(bucket_name,
#       4                         f'fhv_tripdata/fhv_tripdata_{year}-{month:02}.parquet',
#       5                         f'week_4/fhv_tripdata/fhv_tripdata_{year}-{month:02}.parquet'
#       6                )
#       7     print(f'{month} done')
#
# Cell In[7], line 6, in upload_blob(bucket_name, source_file_name, destination_blob_name)
#       4 bucket = storage_client.get_bucket(bucket_name)
#       5 blob = bucket.blob(destination_blob_name)
# ----> 6 blob.upload_from_filename(source_file_name)
#
# File /usr/local/lib/python3.11/site-packages/google/cloud/storage/blob.py:2929, in Blob.upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2807 def upload_from_filename(
#    2808     self,
#    2809     filename,
#    (...)
#    2820     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2821 ):
#    2822     """Upload this blob's contents from the content of a named file.
#    2823
#    2824     The content type of the upload will be determined in order
#    (...)
#    2926         are respected.
#    2927     """
# -> 2929     self._handle_filename_and_upload(
#    2930         filename,
#    2931         content_type=content_type,
#    2932         num_retries=num_retries,
#    2933         client=client,
#    2934         predefined_acl=predefined_acl,
#    2935         if_generation_match=if_generation_match,
#    2936         if_generation_not_match=if_generation_not_match,
#    2937         if_metageneration_match=if_metageneration_match,
#    2938         if_metageneration_not_match=if_metageneration_not_match,
#    2939         timeout=timeout,
#    2940         checksum=checksum,
#    2941         retry=retry,
#    2942     )
#
# File /usr/local/lib/python3.11/site-packages/google/cloud/storage/blob.py:2799, in Blob._handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2797 with open(filename, "rb") as file_obj:
#    2798     total_bytes = os.fstat(file_obj.fileno()).st_size
# -> 2799     self._prep_and_do_upload(
#    2800         file_obj,
#    2801         content_type=content_type,
#    2802         size=total_bytes,
#    2803         *args,
#    2804         **kwargs,
#    2805     )
#
# File /usr/local/lib/python3.11/site-packages/google/cloud/storage/blob.py:2607, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2604 predefined_acl = ACL.validate_predefined(predefined_acl)
#    2606 try:
# -> 2607     created_json = self._do_upload(
#    2608         client,
#    2609         file_obj,
#    2610         content_type,
#    2611         size,
#    2612         num_retries,
#    2613         predefined_acl,
#    2614         if_generation_match,
#    2615         if_generation_not_match,
#    2616         if_metageneration_match,
#    2617         if_metageneration_not_match,
#    2618         timeout=timeout,
#    2619         checksum=checksum,
#    2620         retry=retry,
#    2621         command=command,
#    2622     )
#    2623     self._set_properties(created_json)
#    2624 except resumable_media.InvalidResponse as exc:
#
# File /usr/local/lib/python3.11/site-packages/google/cloud/storage/blob.py:2430, in Blob._do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2413     response = self._do_multipart_upload(
#    2414         client,
#    2415         stream,
#    (...)
#    2427         command=command,
#    2428     )
#    2429 else:
# -> 2430     response = self._do_resumable_upload(
#    2431         client,
#    2432         stream,
#    2433         content_type,
#    2434         size,
#    2435         num_retries,
#    2436         predefined_acl,
#    2437         if_generation_match,
#    2438         if_generation_not_match,
#    2439         if_metageneration_match,
#    2440         if_metageneration_not_match,
#    2441         timeout=timeout,
#    2442         checksum=checksum,
#    2443         retry=retry,
#    2444         command=command,
#    2445     )
#    2447 return response.json()
#
# File /usr/local/lib/python3.11/site-packages/google/cloud/storage/blob.py:2266, in Blob._do_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2264 while not upload.finished:
#    2265     try:
# -> 2266         response = upload.transmit_next_chunk(transport, timeout=timeout)
#    2267     except resumable_media.DataCorruption:
#    2268         # Attempt to delete the corrupted object.
#    2269         self.delete()
#
# File /usr/local/lib/python3.11/site-packages/google/resumable_media/requests/upload.py:515, in ResumableUpload.transmit_next_chunk(self, transport, timeout)
#     511     self._process_resumable_response(result, len(payload))
#     513     return result
# --> 515 return _request_helpers.wait_and_retry(
#     516     retriable_request, self._get_status_code, self._retry_strategy
#     517 )
#
# File /usr/local/lib/python3.11/site-packages/google/resumable_media/requests/_request_helpers.py:178, in wait_and_retry(func, get_status_code, retry_strategy)
#     175 # Check if (another) retry is allowed. If retries are exhausted and
#     176 # no acceptable response was received, raise the retriable error.
#     177 if not retry_strategy.retry_allowed(total_sleep, num_retries):
# --> 178     raise error
#     180 time.sleep(wait_time)
#
# File /usr/local/lib/python3.11/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     153 error = None
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#     157     error = e  # Fall through to retry, if there are retries left.
#
# File /usr/local/lib/python3.11/site-packages/google/resumable_media/requests/upload.py:507, in ResumableUpload.transmit_next_chunk.<locals>.retriable_request()
#     506 def retriable_request():
# --> 507     result = transport.request(
#     508         method, url, data=payload, headers=headers, timeout=timeout
#     509     )
#     511     self._process_resumable_response(result, len(payload))
#     513     return result
#
# File /usr/local/lib/python3.11/site-packages/google/auth/transport/requests.py:541, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     538 remaining_time = guard.remaining_timeout
#     540 with TimeoutGuard(remaining_time) as guard:
# --> 541     response = super(AuthorizedSession, self).request(
#     542         method,
#     543         url,
#     544         data=data,
#     545         headers=request_headers,
#     546         timeout=timeout,
#     547         **kwargs
#     548     )
#     549 remaining_time = guard.remaining_timeout
#     551 # If the response indicated that the credentials needed to be
#     552 # refreshed, then refresh the credentials and re-attempt the
#     553 # request.
#     554 # A stored token may expire between the time it is retrieved and
#     555 # the time the request is made, so we may need to try twice.
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.11/site-packages/requests/adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', TimeoutError('The write operation timed out'))

# %%
# !ls
# Out:
# green_tripdata homework.ipynb

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-10.parquet')

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2020-10-01 00:09:08   2020-10-01 00:11:05              1.0
# 1         1  2020-10-01 00:09:19   2020-10-01 00:19:46              1.0
# 2         1  2020-10-01 00:30:00   2020-10-01 00:39:05              1.0
# 3         2  2020-10-01 00:56:46   2020-10-01 00:57:10              1.0
# 4         2  2020-10-01 00:56:46   2020-10-01 00:57:10              1.0
# 5         1  2020-10-01 00:31:00   2020-10-01 00:37:58              1.0
# 6         1  2020-10-01 00:37:04   2020-10-01 00:39:07              0.0
# 7         1  2020-10-01 00:38:44   2020-10-01 00:51:40              1.0
# 8         2  2020-10-01 00:00:14   2020-10-01 00:05:17              1.0
# 9         2  2020-10-01 00:24:32   2020-10-01 00:31:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.00         1.0                  N           145           145
# 1           2.00         1.0                  Y           238           143
# 2           2.10         1.0                  N           264           230
# 3           0.00         1.0                  N           264           152
# 4           0.00         1.0                  N           264           152
# 5           1.50         1.0                  N            95           102
# 6           0.80         1.0                  N           239           238
# 7           3.80         1.0                  N           141           260
# 8           1.44         1.0                  N           209           232
# 9           2.20         1.0                  N           230           125
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          3.0    0.5      0.5        0.00           0.0
# 1             2          9.5    3.0      0.5        0.00           0.0
# 2             1          9.0    3.0      0.5        2.56           0.0
# 3             3         -2.5   -0.5     -0.5        0.00           0.0
# 4             1          2.5    0.5      0.5        0.00           0.0
# 5             2          7.5    0.5      0.5        0.00           0.0
# 6             1          4.5    3.0      0.5        1.65           0.0
# 7             2         13.0    3.0      0.5        0.00           0.0
# 8             1          6.5    0.5      0.5        5.70           0.0
# 9             1          8.0    0.5      0.5        2.36           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge airport_fee
# 0                    0.3          4.30                   0.0        None
# 1                    0.3         13.30                   2.5        None
# 2                    0.3         15.36                   2.5        None
# 3                   -0.3         -3.80                   0.0        None
# 4                    0.3          3.80                   0.0        None
# 5                    0.3          8.80                   0.0        None
# 6                    0.3          9.95                   2.5        None
# 7                    0.3         16.80                   2.5        None
# 8                    0.3         16.00                   2.5        None
# 9                    0.3         14.16                   2.5        None

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                      object
# dtype: object
